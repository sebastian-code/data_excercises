# %% [markdown]
# # La calidad de los datos suele no ser la mejor.
#
# ### Un ejemplo tomando datos de U.S. Energy Information Administration
#
# Fuente de los datos: [eia.gov](http://www.eia.gov/coal/data.cfm)
#
# ¿Que hacer?
#
# 1. **Revisar los datos** Siempre asuman que los datos tienen errores.
# 2. **Limpiar y estandarizar** Es necesario procesar los datos para que sean homogeneos y confiables.

# %%
# %matplotlib inline

# %%
import asyncio
import glob

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
#import seaborn as sns
import xlrd

from IPython.display import IFrame
from xml.sax import ContentHandler, parse

# %%
# Veamos como se ve la fuente de los datos metiendola en un IFrame
IFrame("http://www.eia.gov/coal/data.cfm", width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="http://www.eia.gov/coal/data.cfm"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Funcion para manejar la descarga de archivos y guardarlos apropiadamente.
def download_file(url):
    local_filename = url.split('/')[-1]
    r = requests.get(url, stream=True)
    with open(f"big_data_chunks/uncleaned_coal_data/{local_filename}", 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024): 
            if chunk:
                f.write(chunk)

    return local_filename

# %%
# No vamos a escribir a mano la lista de todos los archivos, para ello usamos la dirección tipo de los archivos.
# https://www.eia.gov/coal/data/public/xls/coalpublic1985.xls y descargamos.
for year in range(1983, 2016):
    print(f"Downloading year {year}")
    download_file(f"https://www.eia.gov/coal/data/public/xls/coalpublic{year}.xls")
    print(f"Year {year} downloaded")
# Out:
# Downloading year 1985
# Year 1985 downloaded
# Downloading year 1986
# Year 1986 downloaded
# Downloading year 1987
# Year 1987 downloaded
# Downloading year 1988
# Year 1988 downloaded
# Downloading year 1989
# Year 1989 downloaded
# Downloading year 1990
# Year 1990 downloaded
# Downloading year 1991
# Year 1991 downloaded
# Downloading year 1992
# Year 1992 downloaded
# Downloading year 1993
# Year 1993 downloaded
# Downloading year 1994
# Year 1994 downloaded
# Downloading year 1995
# Year 1995 downloaded
# Downloading year 1996
# Year 1996 downloaded
# Downloading year 1997
# Year 1997 downloaded
# Downloading year 1998
# Year 1998 downloaded
# Downloading year 1999
# Year 1999 downloaded
# Downloading year 2000
# Year 2000 downloaded
# Downloading year 2001
# Year 2001 downloaded
# Downloading year 2002
# Year 2002 downloaded
# Downloading year 2003
# Year 2003 downloaded
# Downloading year 2004
# Year 2004 downloaded
# Downloading year 2005
# Year 2005 downloaded
# Downloading year 2006
# Year 2006 downloaded
# Downloading year 2007
# Year 2007 downloaded
# Downloading year 2008
# Year 2008 downloaded
# Downloading year 2009
# Year 2009 downloaded
# Downloading year 2010
# Year 2010 downloaded
# Downloading year 2011
# Year 2011 downloaded
# Downloading year 2012
# Year 2012 downloaded
# Downloading year 2013
# Year 2013 downloaded
# Downloading year 2014
# Year 2014 downloaded
# Downloading year 2015
# Year 2015 downloaded

# %%
# Un ligero analisis de los datos descargados.
try:
    df_test = pd.read_excel('big_data_chunks/uncleaned_coal_data/coalpublic1986.xls', skiprows=3)
    df_test.head()

except xlrd.XLRDError as e:
    print("Upppssie", e)
# Out:
# Upppssie Unsupported format, or corrupt file: Expected BOF record; found b'<?xml ve'

# %%
# ¿Que paso? Las fuentes de datos parece que tienen problemas.
# Veamos otro archivo.
df_test = pd.read_excel("big_data_chunks/uncleaned_coal_data/coalpublic2016.xls", skiprows=3)
df_test.head()
# Out:
#    Year  MSHA ID           Mine Name Mine State Mine County  \
# 0  2016   103381  Jesse Creek H.W.M.    Alabama        Bibb
# 1  2016   103246          Bear Creek    Alabama    Franklin
# 2  2016   103451         Knight Mine    Alabama    Franklin
# 3  2016   100329        Concord Mine    Alabama   Jefferson
# 4  2016   100627       Flat Top Mine    Alabama   Jefferson
#
#           Mine Status    Mine Type                  Company Type  \
# 0              Active      Surface  Indepedent Producer Operator
# 1              Active      Surface  Indepedent Producer Operator
# 2  Temporarily closed      Surface  Indepedent Producer Operator
# 3              Active  Underground          Operating Subsidiary
# 4              Active      Surface  Indepedent Producer Operator
#
#       Operation Type               Operating Company  \
# 0          Mine only         Jesse Creek Mining, Llc
# 1          Mine only  Yellowhammer Energy Solutions,
# 2          Mine only  Birmingham Coal & Coke Co., In
# 3  Preparation Plant         Oak Grove Resources Llc
# 4          Mine only          Cedar Lake Mining, Inc
#
#                    Operating Company Address                      Union Code  \
# 0    1615 Kent Dairy Rd, Alabaster, AL 35007                             NaN
# 1   912 Edenton Street, Birmingham, AL 35242                             NaN
# 2               P.O. Box 354, Lynn, AL 35242                             NaN
# 3  8360 Taylors Ferry Rd, Hueytown, AL 35023  United Mine Workers Of America
# 4         7802 Highway 78, Cordova, AL 35550                             NaN
#
#     Coal Supply Region  Production (short tons)  Average Employees  \
# 0  Appalachia Southern                    37786                  6
# 1  Appalachia Southern                    43155                 21
# 2  Appalachia Southern                    22218                 19
# 3  Appalachia Southern                        0                 43
# 4  Appalachia Southern                   281668                 46
#
#    Labor Hours
# 0        14235
# 1        13278
# 2        11158
# 3        93811
# 4       126268

# %%
# Tomado sin mucha vergüenza de aquí https://www.oreilly.com/library/view/python-cookbook-2nd/0596007973/ch12s08.html
class ExcelHandler(ContentHandler):
    def __init__(self):
        self.chars = []
        self.cells = []
        self.rows = []
        self.tables = []
        
    def characters(self, content):
        self.chars.append(content)
        
    def startElement(self, name, atts):
        if name=="Cell":
            self.chars = []
            
        elif name=="Row":
            self.cells=[]
            
        elif name=="Table":
            self.rows = []
            
    def endElement(self, name):
        if name=="Cell":
            self.cells.append(''.join(self.chars))
            
        elif name=="Row":
            self.rows.append(self.cells)
            
        elif name=="Table":
            self.tables.append(self.rows)


def create_file(org_file_addr, df):
    new_addr = 'big_data_chunks/cleaned_coal_data/coal_prod_' + org_file_addr[-8:-4] + '.xlsx'
    df.to_excel(new_addr)

    
def transform_xlrdfiles(file_name):
    excel_handler = ExcelHandler()
    parse(file_name, excel_handler)
    df = pd.DataFrame(excel_handler.tables[0][4:], columns=excel_handler.tables[0][3])
    create_file(file_name, df)

# %%
unclean_list = glob.glob('big_data_chunks/uncleaned_coal_data/*.xls')
for file in unclean_list:
    print('Procesando:', file)
    try:
        df = pd.read_excel(file, skiprows=3)
        create_file(file, df)
        print(' ...Ok')

    except:
        transform_xlrdfiles(file)
        print(' ...Ok')
    
print('\n¡Proceso Terminado!')
# Out:
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2009.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1996.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1999.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2012.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2003.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1994.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2007.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2010.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1993.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1986.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1990.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1995.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2001.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2014.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1992.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1998.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2015.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2008.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1988.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2011.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2002.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1997.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2005.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1989.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1987.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2013.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2016.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2000.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2004.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1985.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic2006.xls
#  ...Ok
# Procesando: big_data_chunks/uncleaned_coal_data/coalpublic1991.xls
#  ...Ok
#
# ¡Proceso Terminado!

# %%
clean_list = glob.glob('big_data_chunks/cleaned_coal_data/*.xlsx')
df = pd.DataFrame()
for el in clean_list:
    df = pd.concat((df, pd.read_excel(el, index_col=False, sort=True)))
# Out:
# /home/maestro/.virtualenvs/datas/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
df1 = pd.read_excel("cleaned_data/coal_prod_2001.xlsx", index_col=False)
df2 = pd.read_excel("cleaned_data/coal_prod_2002.xlsx", index_col=False)
df3 = pd.read_excel("cleaned_data/coal_prod_2003.xlsx", index_col=False)
df4 = pd.read_excel("cleaned_data/coal_prod_2004.xlsx", index_col=False)
df5 = pd.read_excel("cleaned_data/coal_prod_2005.xlsx", index_col=False)
df6 = pd.read_excel("cleaned_data/coal_prod_2006.xlsx", index_col=False)
df7 = pd.read_excel("cleaned_data/coal_prod_2007.xlsx", index_col=False)
df8 = pd.read_excel("cleaned_data/coal_prod_2008.xlsx", index_col=False)
df9 = pd.read_excel("cleaned_data/coal_prod_2009.xlsx", index_col=False)
df10 = pd.read_excel("cleaned_data/coal_prod_2010.xlsx", index_col=False)
df11 = pd.read_excel("cleaned_data/coal_prod_2011.xlsx", index_col=False)
df12 = pd.read_excel("cleaned_data/coal_prod_2012.xlsx", index_col=False)
df13 = pd.read_excel("cleaned_data/coal_prod_2013.xlsx", index_col=False)
df14 = pd.read_excel("cleaned_data/coal_prod_2014.xlsx", index_col=False)
df15 = pd.read_excel("cleaned_data/coal_prod_2015.xlsx", index_col=False)
df = pd.concat((df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15))

# %%
df
# Out:
#       Average Employees              Coal Supply Region Company Type  \
# 0               37786.0                             NaN      Surface
# 1               43155.0                             NaN      Surface
# 2               22218.0                             NaN      Surface
# 3                   0.0  United Mine Workers Of America  Underground
# 4              281668.0                             NaN      Surface
# 5             1474588.0  United Mine Workers Of America  Underground
# 6             3067565.0  United Mine Workers Of America  Underground
# 7                   0.0                             NaN      Surface
# 8              234852.0                             NaN      Surface
# 9              108420.0                             NaN      Surface
# 10               5870.0                             NaN      Surface
# 11             186784.0                             NaN  Underground
# 12               7412.0                             NaN      Surface
# 13             313259.0                             NaN      Surface
# 14                  0.0                             NaN      Surface
# 15                  0.0                             NaN  Underground
# 16                  0.0                             NaN      Surface
# 17                  0.0                             NaN  Underground
# 18               4011.0                             NaN  Underground
# 19              88526.0                             NaN      Surface
# 20              30344.0                             NaN      Surface
# 21             343771.0  United Mine Workers Of America  Underground
# 22              18382.0                             NaN      Surface
# 23              87768.0                             NaN      Surface
# 24             117057.0  United Mine Workers Of America      Surface
# 25            2324188.0  United Mine Workers Of America  Underground
# 26                  0.0                             NaN      Surface
# 27                  0.0                             NaN  Underground
# 28              68468.0                             NaN      Surface
# 29              36396.0                             NaN      Surface
# ...                 ...                             ...          ...
# 1768          3043110.0                             NaN  Underground
# 1769             9740.0                             NaN       Refuse
# 1770           118564.0                             NaN       Refuse
# 1786   Covol Fuels Alabama No.4, Llc  Appalachia Southern
# 1787   Covol Fuels Alabama No.7, Llc  Appalachia Southern
# 1788             Hawkins Refuse Site  Appalachia Northern
# 1789                         Phoenix  Appalachia Northern
# 1790               Mary Lee # 1 Mine  Appalachia Southern
# 1791                       Dredge #1   Appalachia Central
# 1792  Johnson Fork Refuse Project #1   Appalachia Central
# 1793                     Haymond Aml   Appalachia Central
# 1794         Duquoin Carbon Recovery       Illinois Basin
# 1795  Minuteman Fines Recovery Plant       Illinois Basin
# 1796               Turkey Pen Refuse   Appalachia Central
# 1797                Big Sandy Refuse   Appalachia Central
#
#                                Mine Type           Operating Company  \
# 0                                 Active                   Mine only
# 1                                 Active                   Mine only
# 2                     Temporarily closed                   Mine only
# 3                                 Active           Preparation Plant
# 4                                 Active                   Mine only
# 5                                 Active                   Mine only
# 6                                 Active  Mine and Preparation Plant
# 7                                 Active           Preparation Plant
# 8                                 Active                   Mine only
# 9                                 Active                   Mine only
# 10                    Temporarily closed                   Mine only
# 11                                Active                   Mine only
# 12                                Active                   Mine only
# 13                                Active                   Mine only
# 14                                Active           Preparation Plant
# 15                                Active           Preparation Plant
# 16                                Active           Preparation Plant
# 17                                Active           Preparation Plant
# 18                 Permanently abandoned                   Mine only
# 19                    Temporarily closed                   Mine only
# 20                                Active                   Mine only
# 21                                Active  Mine and Preparation Plant
# 22                                Active                   Mine only
# 23                                Active                   Mine only
# 24                                Active  Mine and Preparation Plant
# 25                                Active  Mine and Preparation Plant
# 26                                Active           Preparation Plant
# 27                                Active           Preparation Plant
# 28                                Active                   Mine only
# 29                    Temporarily closed                   Mine only
# ...                                  ...                         ...
# 1768                              Active                   Mine only
# 1769                  Temporarily closed                   Mine only
# 1770                              Active  Mine and Preparation Plant
# 1771                              Active                   Mine only
# 1772                              Active                   Mine only
# 1773                              Active                   Mine only
# 1774                              Active                   Mine only
# 1775                              Active  Mine and Preparation Plant
# 1776                              Active                   Mine only
# 1777                  Temporarily closed                   Mine only
# 1778                              Active  Mine and Preparation Plant
# 1779                              Active                   Mine only
# 1780                              Active  Mine and Preparation Plant
# 1781                              Active  Mine and Preparation Plant
# 1782                              Active                   Mine only
# 1783                              Active                   Mine only
# 1784                              Active                   Mine only
# 1785                              Active  Mine and Preparation Plant
# 1786                              Active  Mine and Preparation Plant
# 1787  Active, men working, not producing  Mine and Preparation Plant
# 1788  Active, men working, not producing                   Mine only
# 1789                              Active           Preparation Plant
# 1790  Active, men working, not producing                   Mine only
# 1791                              Active                   Mine only
# 1792                  Temporarily closed                   Mine only
# 1793                              Active                   Mine only
# 1794                              Active                   Mine only
# 1795  Active, men working, not producing  Mine and Preparation Plant
# 1796                              Active                   Mine only
# 1797                  Temporarily closed                   Mine only
#
#            Operating Company Address                Operation Type  \
# 0            Jesse Creek Mining, Llc  Indepedent Producer Operator
# 1     Yellowhammer Energy Solutions,  Indepedent Producer Operator
# 2     Birmingham Coal & Coke Co., In  Indepedent Producer Operator
# 3            Oak Grove Resources Llc          Operating Subsidiary
# 4             Cedar Lake Mining, Inc  Indepedent Producer Operator
# 5            Oak Grove Resources Llc          Operating Subsidiary
# 1796        Clintwood Elkhorn Mining  Indepedent Producer Operator
# 1797             Landfall Mining Inc  Indepedent Producer Operator
#
#              Production (short tons)  \
# 0                Appalachia Southern
# 1                Appalachia Southern
# 2                Appalachia Southern
# 3                Appalachia Southern
# 4                Appalachia Southern
# 5                Appalachia Southern
# 6                Appalachia Southern
# 7                Appalachia Southern
# 8                Appalachia Southern
# 9                Appalachia Southern
# 10               Appalachia Southern
# 11               Appalachia Southern
# 12               Appalachia Southern
# 13               Appalachia Southern
# 14               Appalachia Southern
# 15               Appalachia Southern
# 16               Appalachia Southern
# 17               Appalachia Southern
# 18               Appalachia Southern
# 19               Appalachia Southern
# 20               Appalachia Southern
# 21               Appalachia Southern
# 22               Appalachia Southern
# 23               Appalachia Southern
# 24               Appalachia Southern
# 25               Appalachia Southern
# 26               Appalachia Southern
# 27               Appalachia Southern
# 28               Appalachia Southern
# 29               Appalachia Southern
# ...                              ...
# 1768          Western Energy Workers
# 1769                             NaN
# 1770                             NaN
# 1771                             NaN
# 1772                             NaN
# 1773                             NaN
# 1774                             NaN
# 1775                             NaN
# 1776                             NaN
# 1777                             NaN
# 1778                             NaN
# 1779                             NaN
# 1780                             NaN
# 1781                             NaN
# 1782                             NaN
# 1783                             NaN
# 1784  United Mine Workers of America
# 1785                             NaN
# 1786                             NaN
# 1787                             NaN
# 1788                             NaN
# 1789                             NaN
# 1790                             NaN
# 1791                             NaN
# 1792                             NaN
# 1793                             NaN
# 1794                             NaN
# 1795                             NaN
# 1796                             NaN
# 1797                             NaN
#
#                                              Union Code  Year
# 0               1615 Kent Dairy Rd, Alabaster, AL 35007     0
# 1              912 Edenton Street, Birmingham, AL 35242     1
# 2                          P.O. Box 354, Lynn, AL 35242     2
# 3             8360 Taylors Ferry Rd, Hueytown, AL 35023     3
# 4                    7802 Highway 78, Cordova, AL 35550     4
# 5             8360 Taylors Ferry Rd, Hueytown, AL 35023     5
# 6                     P.O. Box 133, Brookwood, AL 35444     6
# 7                    7802 Highway 78, Cordova, AL 35550     7
# 8                    7802 Highway 78, Cordova, AL 35550     8
# 9                    7802 Highway 78, Parrish, AL 35550     9
# 10                        P.O. Box 122, Vance, AL 35490    10
# 11                    218 Highway 195, Jasper, AL 35503    11
# 12                17160 Lock 17 Rd, Brookwood, AL 35444    12
# 13                     P.O. Box 1190, Sumiton, AL 35148    13
# 14              1615 Kent Dairy Rd, Alabaster, AL 35007    14
# 15              1615 Kent Dairy Rd, Alabaster, AL 35007    15
# 16                  4636 Scarborough Dr, Lutz, FL 33559    16
# 17                  4636 Scarborough Dr, Lutz, FL 33559    17
# 18            1615 Kent Dairy Road, Alabaster, AL 35007    18
# 19              1615 Kent Dairy Rd, Alabaster, AL 35007    19
# 20                 1615 Kent Dairy, Alabaster, AL 35007    20
# 21              14730 Lock 17 Road, Brookwood, AL 35444    21
# 22                   P.O. Box 770, Cottondale, AL 35453    22
# 23                        P.O. Box 122, Vance, AL 35490    23
# 24                       7802 Hwy 78, Cordova, AL 35550    24
# 25                      P.O. Box 1549, Jasper, AL 35501    25
# 26                    218 Highway 195, Jasper, AL 35503    26
# 1  Indepedent Producer Operator     Appalachia Southern
# 2  Indepedent Producer Operator     Appalachia Southern
# 3          Operating Subsidiary     Appalachia Southern
# 4  Indepedent Producer Operator     Appalachia Southern
#
#                                   Union Code
# 0    1615 Kent Dairy Rd, Alabaster, AL 35007
# 1   912 Edenton Street, Birmingham, AL 35242
# 2               P.O. Box 354, Lynn, AL 35242
# 3  8360 Taylors Ferry Rd, Hueytown, AL 35023
# 4         7802 Highway 78, Cordova, AL 35550

# %%
new_columns = {
                'Average Employees': 'production_short_tons',
                'Company Type': 'mine_type',
                'Labor Hours': 'average_employees',
                'MSHA ID': 'year',
                'Mine Basin': 'mine_county',
                'Mine County': 'mine_state',
                'Mine Name': 'MSHA_ID',
                'Mine State': 'mine_name',
                'Mine Status': 'mine_basin',
                'Mine Type': 'mine_status',
                'Operating Company': 'operation_type',
                'Operating Company Address': 'operating_company',
                'Operation Type': 'company_type',
                'Production (short tons)': 'union_code',
                'Union Code': 'operating_company_address',
              }
df.rename(inplace=True, columns=new_columns)

# %%
df.head()
# Out:
#    production_short_tons    mine_type average_employees  year mine_county  \
# 0                37786.0      Surface                 6  2016         NaN
# 1                43155.0      Surface                21  2016         NaN
# 2                22218.0      Surface                19  2016         NaN
# 3                    0.0  Underground                43  2016         NaN
# 4               281668.0      Surface                46  2016         NaN
#
#   mine_state MSHA_ID           mine_name mine_basin         mine_status  \
# 0    Alabama  103381  Jesse Creek H.W.M.       Bibb              Active
# 1    Alabama  103246          Bear Creek   Franklin              Active
# 2    Alabama  103451         Knight Mine   Franklin  Temporarily closed
# 3    Alabama  100329        Concord Mine  Jefferson              Active
# 4    Alabama  100627       Flat Top Mine  Jefferson              Active
#
#       operation_type               operating_company  \
# 0          Mine only         Jesse Creek Mining, Llc
# 1          Mine only  Yellowhammer Energy Solutions,
# 2          Mine only  Birmingham Coal & Coke Co., In
# 3  Preparation Plant         Oak Grove Resources Llc
# 4          Mine only          Cedar Lake Mining, Inc
#
#                    company_type           union_code  \
# 0  Indepedent Producer Operator  Appalachia Southern
# 1  Indepedent Producer Operator  Appalachia Southern
# 2  Indepedent Producer Operator  Appalachia Southern
# 3          Operating Subsidiary  Appalachia Southern
# 4  Indepedent Producer Operator  Appalachia Southern
#
#                    operating_company_address
# 0    1615 Kent Dairy Rd, Alabaster, AL 35007
# 1   912 Edenton Street, Birmingham, AL 35242
# 2               P.O. Box 354, Lynn, AL 35242
# 3  8360 Taylors Ferry Rd, Hueytown, AL 35023
# 4         7802 Highway 78, Cordova, AL 35550

# %%
df.set_index('MSHA_ID', inplace=True)

# %%
df.head()
# Out:
#          production_short_tons    mine_type average_employees  year  \
# MSHA_ID
# 103381                 37786.0      Surface                 6  2016
# 103246                 43155.0      Surface                21  2016
# 103451                 22218.0      Surface                19  2016
# 100329                     0.0  Underground                43  2016
# 100627                281668.0      Surface                46  2016
#
#         mine_county mine_state           mine_name mine_basin  \
# MSHA_ID
# 103381          NaN    Alabama  Jesse Creek H.W.M.       Bibb
# 103246          NaN    Alabama          Bear Creek   Franklin
# 103451          NaN    Alabama         Knight Mine   Franklin
# 100329          NaN    Alabama        Concord Mine  Jefferson
# 100627          NaN    Alabama       Flat Top Mine  Jefferson
#
#                 mine_status     operation_type  \
# MSHA_ID
# 103381               Active          Mine only
# 103246               Active          Mine only
# 103451   Temporarily closed          Mine only
# 100329               Active  Preparation Plant
# 100627               Active          Mine only
#
#                       operating_company                  company_type  \
# MSHA_ID
# 103381          Jesse Creek Mining, Llc  Indepedent Producer Operator
# 103246   Yellowhammer Energy Solutions,  Indepedent Producer Operator
# 103451   Birmingham Coal & Coke Co., In  Indepedent Producer Operator
# 100329          Oak Grove Resources Llc          Operating Subsidiary
# 100627           Cedar Lake Mining, Inc  Indepedent Producer Operator
#
#                   union_code                  operating_company_address
# MSHA_ID
# 103381   Appalachia Southern    1615 Kent Dairy Rd, Alabaster, AL 35007
# 103246   Appalachia Southern   912 Edenton Street, Birmingham, AL 35242
# 103451   Appalachia Southern               P.O. Box 354, Lynn, AL 35242
# 100329   Appalachia Southern  8360 Taylors Ferry Rd, Hueytown, AL 35023
# 100627   Appalachia Southern         7802 Highway 78, Cordova, AL 35550

# %%
# Mirando los datos, creo que hay un error tipografico.
df['company_type'].unique()
# Out:
# array(['Indepedent Producer Operator', 'Operating Subsidiary',
#        'Contractor', '-'], dtype=object)

# %%
# Corrijamos el valor equivocado.
df.loc[df['company_type'] == 'Indepedent Producer Operator', 'company_type'] = 'Independent Producer Operator'
df.head()
# Out:
#          production_short_tons    mine_type average_employees  year  \
# MSHA_ID
# 103381                 37786.0      Surface                 6  2016
# 103246                 43155.0      Surface                21  2016
# 103451                 22218.0      Surface                19  2016
# 100329                     0.0  Underground                43  2016
# 100627                281668.0      Surface                46  2016
#
#         mine_county mine_state           mine_name mine_basin  \
# MSHA_ID
# 103381          NaN    Alabama  Jesse Creek H.W.M.       Bibb
# 103246          NaN    Alabama          Bear Creek   Franklin
# 103451          NaN    Alabama         Knight Mine   Franklin
# 100329          NaN    Alabama        Concord Mine  Jefferson
# 100627          NaN    Alabama       Flat Top Mine  Jefferson
#
#                 mine_status     operation_type  \
# MSHA_ID
# 103381               Active          Mine only
# 103246               Active          Mine only
# 103451   Temporarily closed          Mine only
# 100329               Active  Preparation Plant
# 100627               Active          Mine only
#
#                       operating_company                   company_type  \
# MSHA_ID
# 103381          Jesse Creek Mining, Llc  Independent Producer Operator
# 103246   Yellowhammer Energy Solutions,  Independent Producer Operator
# 103451   Birmingham Coal & Coke Co., In  Independent Producer Operator
# 100329          Oak Grove Resources Llc           Operating Subsidiary
# 100627           Cedar Lake Mining, Inc  Independent Producer Operator
#
#                   union_code                  operating_company_address
# MSHA_ID
# 103381   Appalachia Southern    1615 Kent Dairy Rd, Alabaster, AL 35007
# 103246   Appalachia Southern   912 Edenton Street, Birmingham, AL 35242
# 103451   Appalachia Southern               P.O. Box 354, Lynn, AL 35242
# 100329   Appalachia Southern  8360 Taylors Ferry Rd, Hueytown, AL 35023
# 100627   Appalachia Southern         7802 Highway 78, Cordova, AL 35550

# %% [markdown]
# # Y para terminar:
#
# ## Un producto terminado
#
# Un conjunto de datos limpio (mayormente), ordenado y listo para ser analizado.

# %%
df.to_excel("cleaned_data/coal_prod_cleaned.xlsx")
